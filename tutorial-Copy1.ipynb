# %% [markdown]
# #### **Imports**

# %%
## import essential modules 
import qumcmc 
from qumcmc.basic_utils import *
# from qumcmc.energy_models import IsingEnergyFunction
from qumcmc.energy_models import IsingEnergyFunction, Exact_Sampling

from qumcmc.classical_mcmc_routines import classical_mcmc
from qumcmc.quantum_mcmc_routines_qulacs import quantum_enhanced_mcmc     #for Qulacs Simulator backend (** Faster )
# from qumcmc.quantum_mcmc_routines_qiskit import quantum_enhanced_mcmc   #for qiskit Aer's Simulator backend 

from qumcmc.trajectory_processing import calculate_running_js_divergence, calculate_running_kl_divergence, calculate_runnning_magnetisation, get_trajectory_statistics

# %%
import seaborn as sns
sns.set()

# %% [markdown]
# #### **Define the Energy Model**

# %%
### class to generate BAS dataset of arbitrary gridsize.
from itertools import permutations, product
class bas_dataset:
    def __init__(self, grid_size:int):
        self.grid_size=grid_size
        all_combn=[''.join(p) for p in product('01',repeat=self.grid_size)]
        all_combn.sort(key=lambda s: s.count('1'))
        all_combn.pop(0);all_combn.pop(-1)
        self.__all_combn=all_combn
        self.bas_dict=self.bars_and_stripes_dataset()
        self.dataset= self.bas_dict['stripes']+self.bas_dict['bars'] + self.bas_dict.get("both", [])
    
    def vertical_stripes(self):
        vert_stripes=[j*self.grid_size for j in self.__all_combn]
        return vert_stripes

    def horizontal_bars(self):
        hor_bars=[]
        for l in self.__all_combn:
            st=""
            for j in l:
                st=st+j*self.grid_size
            hor_bars.append(st)
        return hor_bars

    def bars_and_stripes_dataset(self):
        bas_dict={'stripes':self.vertical_stripes(),
                  'bars':self.horizontal_bars(),
                  # "both": ["0"*self.grid_size*self.grid_size, "1"*self.grid_size*self.grid_size]
                 }
        return bas_dict

    ### create matrix of bitstring: meant for plotting
    def bit_string_to_2d_matrix(self,bitstring, array_shape:int):
        len_bs=len(bitstring)
        list_bs_int=[eval(i) for i in list(bitstring)]
        arr_bs=np.reshape(list_bs_int,(array_shape, array_shape))
        return arr_bs

    ### plot pixels
    def draw_pixelplot(self,bitstring:str,array_shape:int):
        im_array=self.bit_string_to_2d_matrix(bitstring,array_shape)
        plt.title(f"pixel plot for bitstring: {bitstring}")
        pixel_plot=plt.imshow(im_array,cmap='Greens',interpolation='nearest')
        plt.colorbar(pixel_plot)
        plt.show()

# %%
def hebbing_learning(list_bas_state:list):
    size=len(list_bas_state[0])
    wts=0
    for i in list_bas_state:
        arr=np.array([-1 if elem == "0" else 1 for elem in i])
        array=np.reshape(arr,(size,1));array_t=np.transpose(array)
        wts+=array@array_t
    wts=wts-len(list_bas_state)*np.identity(size)
    return wts

# %%
gridsize=3
bas=bas_dataset(grid_size=gridsize)
wt=hebbing_learning(bas.dataset)
# np.shape(wt);wt

# %%
# define the model
np.random.seed(610358)# should always be in the same cell!  ## best seed -> 610358
n_spins = gridsize*gridsize

## construct problem Hamiltonian ##
shape_of_J=(n_spins,n_spins)

## defining J matrix (mutual 1-1 interaction)
# J =  np.round(np.random.choice([+1, 0, -1], size=(n_spins, n_spins)), decimals=2) 
# J =  np.random.uniform(low= -2, high= 2, size= shape_of_J )
# J = 0.5 * (J + J.transpose() )
# J = np.round( J - np.diag(np.diag(J)) , decimals= 3)

#evaluating J for BAS dataset
J=-1*wt   #np.array([[0,0,0,4],[0,0,4,0],[0,4,0,0],[4,0,0,0]])
# defining h
#h = np.round(0.5 * np.random.randn(n_spins), decimals=2)
#h = np.round(np.random.uniform(low= -1, high = 1, size= (n_spins)), decimals=2)
h=np.zeros(np.shape(J)[0])
# instantiate the model
#model = IsingEnergyFunction(J, h, name= 'my_model')
model=IsingEnergyFunction(J,h,name=f"BAS data of gridsize {np.shape(J)[0]}")

# %%
model.get_J
# Out:
# array([[-0., -4., -4., -4.,  4.,  4., -4.,  4.,  4.],
#        [-4., -0., -4.,  4., -4.,  4.,  4., -4.,  4.],
#        [-4., -4., -0.,  4.,  4., -4.,  4.,  4., -4.],
#        [-4.,  4.,  4., -0., -4., -4., -4.,  4.,  4.],
#        [ 4., -4.,  4., -4., -0., -4.,  4., -4.,  4.],
#        [ 4.,  4., -4., -4., -4., -0.,  4.,  4., -4.],
#        [-4.,  4.,  4., -4.,  4.,  4., -0., -4., -4.],
#        [ 4., -4.,  4.,  4., -4.,  4., -4., -0., -4.],
#        [ 4.,  4., -4.,  4.,  4., -4., -4., -4., -0.]])

# %%
model.model_summary()
# Out:
# =============================================
#             MODEL : BAS data of gridsize 9
# =============================================
# Non-zero Interactions (J) : 36 / 36
# Non-zero Bias (h) : 0 / 9
# ---------------------------------------------
# Average Interaction Strength <|J|> :  3.5555555555555554
# Average Bias Strength <|h|>:  0.0
# alpha :  0.125
# ---------------------------------------------

# %%
## checking qulacs fn_qc_h1 term.
# from qulacs.gate import Pauli,X
# gate_x=X(2)
# print("gate_x:")
# print(gate_x.get_matrix())
# target_list=[2]
# pauli_index=[1]
# gate_2=Pauli(target_list,pauli_index)
# print("gate_2")
# print(gate_2.get_matrix())
# # these two are the same thing
# multi_x_gate=Pauli([0,1],[2,1])
# print("multi_x_gate")
# print(multi_x_gate.get_matrix())

# %% [markdown]
# #### **Exact Analysis**

# %%
## set current beta
beta = 1#1.100209

## run exact sampling over all possible configurations 
exact_sampled_model = Exact_Sampling(model, beta)

# %%
bas.dataset.sort()
bas.dataset,len(bas.dataset)
# Out:
# (['000000111',
#   '000111000',
#   '000111111',
#   '001001001',
#   '010010010',
#   '011011011',
#   '100100100',
#   '101101101',
#   '110110110',
#   '111000000',
#   '111000111',
#   '111111000'],
#  12)

# %%
## get the distribution from model
bpd = exact_sampled_model.boltzmann_pd

## exact sampling summary
plt.figure(figsize=(17,10))

exact_sampled_model.sampling_summary(show_threshold=1e-10)
plt.yscale("log")
# Out:
# =============================================
#      MODEL : BAS data of gridsize 9 |  beta : 1
# =============================================
# Num Most Probable States : 102
# Entropy : 3.5849606926186035
# ---------------------------------------------

# %% [markdown]
# #### **Run Classical MCMC**

# %%
initial_state = bas.dataset[0]
initial_state
# Out:
# '000000111'

# %%
steps = 10000
cl_chain =classical_mcmc(
    n_hops=steps,
    model=model,
    initial_state=initial_state,
    # return_last_n_states=10,
    temperature=1/beta,
)

# %%
cl_statistic = get_trajectory_statistics(cl_chain, exact_sampled_model, verbose=False)

# %% [markdown]
# #### **Run Quantum Enhaned MCMC**

# %%
steps = 10000
qamcmc_chain_1 = quantum_enhanced_mcmc(
    n_hops=steps,
    initial_state=initial_state,
    model=model,
    temperature=1/beta
)

# %%
steps =10000
qamcmc_chain_2 = quantum_enhanced_mcmc(
    n_hops=steps,
    initial_state=initial_state,
    model=model,
    temperature=1/beta,single_qubit_mixer=False, pauli_index_list=[1]*gridsize,
    gamma_range= (0.01,0.1)
)

# %%
qumcm1_statistic = get_trajectory_statistics(qamcmc_chain_1, exact_sampled_model, verbose= False)
qumcm2_statistic = get_trajectory_statistics(qamcmc_chain_2, exact_sampled_model, verbose= False)

# %%
qamcmc_chain_1.states
# Out:
# [MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  MCMCState(bitstring='0011', accepted=True),
#  ...]

# %% [markdown]
# #### **Sampled Distributions**

# %%
distributions_to_plot = [exact_sampled_model.boltzmann_pd, cl_chain.get_accepted_dict(normalize= True), 
                        qamcmc_chain_1.get_accepted_dict(normalize= True),qamcmc_chain_2.get_accepted_dict(normalize= True) ]
plot_multiple_bargraphs(distributions_to_plot, ['Exact Distribution', 'Classical-Uniform', 'Quantum-Xi','Quantum-XiXi+1'], list_normalise= [False, False, False,False], plot_first_few=15)

# %%
qamcmc_chain_2.get_accepted_dict(normalize= True)
# Out:
# Counter({'000000111': 0.1040895910408959,
#          '011011011': 0.09319068093190681,
#          '001001001': 0.11768823117688232,
#          '101101101': 0.0836916308369163,
#          '111111000': 0.0695930406959304,
#          '111000111': 0.08999100089991001,
#          '111000000': 0.0608939106089391,
#          '010010010': 0.0932906709329067,
#          '100100100': 0.0898910108989101,
#          '000111000': 0.08339166083391661,
#          '110110110': 0.047995200479952004,
#          '000111111': 0.06629337066293371})

# %%
from qumcmc.prob_dist import kl_divergence

# %%
exact_sampled_model.boltzmann_pd
# Out:
# {'000000111': 0.08333326299889905,
#  '000111000': 0.08333326299889905,
#  '000111111': 0.08333326299889905,
#  '001001001': 0.08333326299889905,
#  '010010010': 0.08333326299889905,
#  '011011011': 0.08333326299889905,
#  '100100100': 0.08333326299889905,
#  '101101101': 0.08333326299889905,
#  '110110110': 0.08333326299889905,
#  '111000000': 0.08333326299889905,
#  '111000111': 0.08333326299889905,
#  '111111000': 0.08333326299889905,
#  '000001111': 9.377923311507073e-09,
#  '000010111': 9.377923311507073e-09,
#  '000011011': 9.377923311507073e-09,
#  '000011111': 9.377923311507073e-09,
#  '000100111': 9.377923311507073e-09,
#  '000101101': 9.377923311507073e-09,
#  '000101111': 9.377923311507073e-09,
#  '000110110': 9.377923311507073e-09,
#  '000110111': 9.377923311507073e-09,
#  '000111001': 9.377923311507073e-09,
#  '000111010': 9.377923311507073e-09,
#  '000111011': 9.377923311507073e-09,
#  '000111100': 9.377923311507073e-09,
#  '000111101': 9.377923311507073e-09,
#  '000111110': 9.377923311507073e-09,
#  '001000111': 9.377923311507073e-09,
#  '001001011': 9.377923311507073e-09,
#  '001001101': 9.377923311507073e-09,
#  '001001111': 9.377923311507073e-09,
#  '001011001': 9.377923311507073e-09,
#  '001011011': 9.377923311507073e-09,
#  '001101001': 9.377923311507073e-09,
#  '001101101': 9.377923311507073e-09,
#  '001111000': 9.377923311507073e-09,
#  '001111001': 9.377923311507073e-09,
#  '010000111': 9.377923311507073e-09,
#  '010010011': 9.377923311507073e-09,
#  '010010110': 9.377923311507073e-09,
#  '010010111': 9.377923311507073e-09,
#  '010011010': 9.377923311507073e-09,
#  '010011011': 9.377923311507073e-09,
#  '010110010': 9.377923311507073e-09,
#  '010110110': 9.377923311507073e-09,
#  '010111000': 9.377923311507073e-09,
#  '010111010': 9.377923311507073e-09,
#  '011000011': 9.377923311507073e-09,
#  '011000111': 9.377923311507073e-09,
#  '011001001': 9.377923311507073e-09,
#  '011001011': 9.377923311507073e-09,
#  '011010010': 9.377923311507073e-09,
#  '011010011': 9.377923311507073e-09,
#  '011011000': 9.377923311507073e-09,
#  '011011001': 9.377923311507073e-09,
#  '011011010': 9.377923311507073e-09,
#  '011111000': 9.377923311507073e-09,
#  '100000111': 9.377923311507073e-09,
#  '100100101': 9.377923311507073e-09,
#  '100100110': 9.377923311507073e-09,
#  '100100111': 9.377923311507073e-09,
#  '100101100': 9.377923311507073e-09,
#  '100101101': 9.377923311507073e-09,
#  '100110100': 9.377923311507073e-09,
#  '100110110': 9.377923311507073e-09,
#  '100111000': 9.377923311507073e-09,
#  '100111100': 9.377923311507073e-09,
#  '101000101': 9.377923311507073e-09,
#  '101000111': 9.377923311507073e-09,
#  '101001001': 9.377923311507073e-09,
#  '101001101': 9.377923311507073e-09,
#  '101100100': 9.377923311507073e-09,
#  '101100101': 9.377923311507073e-09,
#  '101101000': 9.377923311507073e-09,
#  '101101001': 9.377923311507073e-09,
#  '101101100': 9.377923311507073e-09,
#  '101111000': 9.377923311507073e-09,
#  '110000110': 9.377923311507073e-09,
#  '110000111': 9.377923311507073e-09,
#  '110010010': 9.377923311507073e-09,
#  '110010110': 9.377923311507073e-09,
#  '110100100': 9.377923311507073e-09,
#  '110100110': 9.377923311507073e-09,
#  '110110000': 9.377923311507073e-09,
#  '110110010': 9.377923311507073e-09,
#  '110110100': 9.377923311507073e-09,
#  '110111000': 9.377923311507073e-09,
#  '111000001': 9.377923311507073e-09,
#  '111000010': 9.377923311507073e-09,
#  '111000011': 9.377923311507073e-09,
#  '111000100': 9.377923311507073e-09,
#  '111000101': 9.377923311507073e-09,
#  '111000110': 9.377923311507073e-09,
#  '111001000': 9.377923311507073e-09,
#  '111001001': 9.377923311507073e-09,
#  '111010000': 9.377923311507073e-09,
#  '111010010': 9.377923311507073e-09,
#  '111011000': 9.377923311507073e-09,
#  '111100000': 9.377923311507073e-09,
#  '111100100': 9.377923311507073e-09,
#  '111101000': 9.377923311507073e-09,
#  '111110000': 9.377923311507073e-09,
#  '000000011': 1.0553462383642616e-15,
#  '000000101': 1.0553462383642616e-15,
#  '000000110': 1.0553462383642616e-15,
#  '000001001': 1.0553462383642616e-15,
#  '000001011': 1.0553462383642616e-15,
#  '000001101': 1.0553462383642616e-15,
#  '000010010': 1.0553462383642616e-15,
#  '000010011': 1.0553462383642616e-15,
#  '000010110': 1.0553462383642616e-15,
#  '000011000': 1.0553462383642616e-15,
#  '000011001': 1.0553462383642616e-15,
#  '000011010': 1.0553462383642616e-15,
#  '000100100': 1.0553462383642616e-15,
#  '000100101': 1.0553462383642616e-15,
#  '000100110': 1.0553462383642616e-15,
#  '000101000': 1.0553462383642616e-15,
#  '000101001': 1.0553462383642616e-15,
#  '000101100': 1.0553462383642616e-15,
#  '000110000': 1.0553462383642616e-15,
#  '000110010': 1.0553462383642616e-15,
#  '000110100': 1.0553462383642616e-15,
#  '001000001': 1.0553462383642616e-15,
#  '001000011': 1.0553462383642616e-15,
#  '001000101': 1.0553462383642616e-15,
#  '001001000': 1.0553462383642616e-15,
#  '001011000': 1.0553462383642616e-15,
#  '001011111': 1.0553462383642616e-15,
#  '001101000': 1.0553462383642616e-15,
#  '001101111': 1.0553462383642616e-15,
#  '001111011': 1.0553462383642616e-15,
#  '001111101': 1.0553462383642616e-15,
#  '001111111': 1.0553462383642616e-15,
#  '010000010': 1.0553462383642616e-15,
#  '010000011': 1.0553462383642616e-15,
#  '010000110': 1.0553462383642616e-15,
#  '010010000': 1.0553462383642616e-15,
#  '010011000': 1.0553462383642616e-15,
#  '010011111': 1.0553462383642616e-15,
#  '010110000': 1.0553462383642616e-15,
#  '010110111': 1.0553462383642616e-15,
#  '010111011': 1.0553462383642616e-15,
#  '010111110': 1.0553462383642616e-15,
#  '010111111': 1.0553462383642616e-15,
#  '011000000': 1.0553462383642616e-15,
#  '011000001': 1.0553462383642616e-15,
#  '011000010': 1.0553462383642616e-15,
#  '011001000': 1.0553462383642616e-15,
#  '011001111': 1.0553462383642616e-15,
#  '011010000': 1.0553462383642616e-15,
#  '011010111': 1.0553462383642616e-15,
#  '011011111': 1.0553462383642616e-15,
#  '011111001': 1.0553462383642616e-15,
#  '011111010': 1.0553462383642616e-15,
#  '011111011': 1.0553462383642616e-15,
#  '100000100': 1.0553462383642616e-15,
#  '100000101': 1.0553462383642616e-15,
#  '100000110': 1.0553462383642616e-15,
#  '100100000': 1.0553462383642616e-15,
#  '100101000': 1.0553462383642616e-15,
#  '100101111': 1.0553462383642616e-15,
#  '100110000': 1.0553462383642616e-15,
#  '100110111': 1.0553462383642616e-15,
#  '100111101': 1.0553462383642616e-15,
#  '100111110': 1.0553462383642616e-15,
#  '100111111': 1.0553462383642616e-15,
#  '101000000': 1.0553462383642616e-15,
#  '101000001': 1.0553462383642616e-15,
#  '101000100': 1.0553462383642616e-15,
#  '101001000': 1.0553462383642616e-15,
#  '101001111': 1.0553462383642616e-15,
#  '101100000': 1.0553462383642616e-15,
#  '101100111': 1.0553462383642616e-15,
#  '101101111': 1.0553462383642616e-15,
#  '101111001': 1.0553462383642616e-15,
#  '101111100': 1.0553462383642616e-15,
#  '101111101': 1.0553462383642616e-15,
#  '110000000': 1.0553462383642616e-15,
#  '110000010': 1.0553462383642616e-15,
#  '110000100': 1.0553462383642616e-15,
#  '110010000': 1.0553462383642616e-15,
#  '110010111': 1.0553462383642616e-15,
#  '110100000': 1.0553462383642616e-15,
#  '110100111': 1.0553462383642616e-15,
#  '110110111': 1.0553462383642616e-15,
#  '110111010': 1.0553462383642616e-15,
#  '110111100': 1.0553462383642616e-15,
#  '110111110': 1.0553462383642616e-15,
#  '111001011': 1.0553462383642616e-15,
#  '111001101': 1.0553462383642616e-15,
#  '111001111': 1.0553462383642616e-15,
#  '111010011': 1.0553462383642616e-15,
#  '111010110': 1.0553462383642616e-15,
#  '111010111': 1.0553462383642616e-15,
#  '111011001': 1.0553462383642616e-15,
#  '111011010': 1.0553462383642616e-15,
#  '111011011': 1.0553462383642616e-15,
#  '111100101': 1.0553462383642616e-15,
#  '111100110': 1.0553462383642616e-15,
#  '111100111': 1.0553462383642616e-15,
#  '111101001': 1.0553462383642616e-15,
#  '111101100': 1.0553462383642616e-15,
#  '111101101': 1.0553462383642616e-15,
#  '111110010': 1.0553462383642616e-15,
#  '111110100': 1.0553462383642616e-15,
#  '111110110': 1.0553462383642616e-15,
#  '111111001': 1.0553462383642616e-15,
#  '111111010': 1.0553462383642616e-15,
#  '111111100': 1.0553462383642616e-15,
#  '000000000': 1.1876357332363507e-22,
#  '000000001': 1.1876357332363507e-22,
#  '000000010': 1.1876357332363507e-22,
#  '000000100': 1.1876357332363507e-22,
#  '000001000': 1.1876357332363507e-22,
#  '000010000': 1.1876357332363507e-22,
#  '000011101': 1.1876357332363507e-22,
#  '000011110': 1.1876357332363507e-22,
#  '000100000': 1.1876357332363507e-22,
#  '000101011': 1.1876357332363507e-22,
#  '000101110': 1.1876357332363507e-22,
#  '000110011': 1.1876357332363507e-22,
#  '000110101': 1.1876357332363507e-22,
#  '001000000': 1.1876357332363507e-22,
#  '001010011': 1.1876357332363507e-22,
#  '001010111': 1.1876357332363507e-22,
#  '001011010': 1.1876357332363507e-22,
#  '001011101': 1.1876357332363507e-22,
#  '001100101': 1.1876357332363507e-22,
#  '001100111': 1.1876357332363507e-22,
#  '001101011': 1.1876357332363507e-22,
#  '001101100': 1.1876357332363507e-22,
#  '001111010': 1.1876357332363507e-22,
#  '001111100': 1.1876357332363507e-22,
#  '010000000': 1.1876357332363507e-22,
#  '010001011': 1.1876357332363507e-22,
#  '010001111': 1.1876357332363507e-22,
#  '010011001': 1.1876357332363507e-22,
#  '010011110': 1.1876357332363507e-22,
#  '010100110': 1.1876357332363507e-22,
#  '010100111': 1.1876357332363507e-22,
#  '010110011': 1.1876357332363507e-22,
#  '010110100': 1.1876357332363507e-22,
#  '010111001': 1.1876357332363507e-22,
#  '010111100': 1.1876357332363507e-22,
#  '011000101': 1.1876357332363507e-22,
#  '011000110': 1.1876357332363507e-22,
#  '011001010': 1.1876357332363507e-22,
#  '011001101': 1.1876357332363507e-22,
#  '011010001': 1.1876357332363507e-22,
#  '011010110': 1.1876357332363507e-22,
#  '011101000': 1.1876357332363507e-22,
#  '011101001': 1.1876357332363507e-22,
#  '011110000': 1.1876357332363507e-22,
#  '011110010': 1.1876357332363507e-22,
#  '011111111': 1.1876357332363507e-22,
#  '100000000': 1.1876357332363507e-22,
#  '100001101': 1.1876357332363507e-22,
#  '100001111': 1.1876357332363507e-22,
#  '100010110': 1.1876357332363507e-22,
#  '100010111': 1.1876357332363507e-22,
#  '100101001': 1.1876357332363507e-22,
#  '100101110': 1.1876357332363507e-22,
#  '100110010': 1.1876357332363507e-22,
#  '100110101': 1.1876357332363507e-22,
#  '100111001': 1.1876357332363507e-22,
#  '100111010': 1.1876357332363507e-22,
#  '101000011': 1.1876357332363507e-22,
#  '101000110': 1.1876357332363507e-22,
#  '101001011': 1.1876357332363507e-22,
#  '101001100': 1.1876357332363507e-22,
#  '101011000': 1.1876357332363507e-22,
#  '101011001': 1.1876357332363507e-22,
#  '101100001': 1.1876357332363507e-22,
#  '101100110': 1.1876357332363507e-22,
#  '101110000': 1.1876357332363507e-22,
#  '101110100': 1.1876357332363507e-22,
#  '101111111': 1.1876357332363507e-22,
#  '110000011': 1.1876357332363507e-22,
#  '110000101': 1.1876357332363507e-22,
#  '110010011': 1.1876357332363507e-22,
#  '110010100': 1.1876357332363507e-22,
#  '110011000': 1.1876357332363507e-22,
#  '110011010': 1.1876357332363507e-22,
#  '110100010': 1.1876357332363507e-22,
#  '110100101': 1.1876357332363507e-22,
#  '110101000': 1.1876357332363507e-22,
#  '110101100': 1.1876357332363507e-22,
#  '110111111': 1.1876357332363507e-22,
#  '111001010': 1.1876357332363507e-22,
#  '111001100': 1.1876357332363507e-22,
#  '111010001': 1.1876357332363507e-22,
#  '111010100': 1.1876357332363507e-22,
#  '111011111': 1.1876357332363507e-22,
#  '111100001': 1.1876357332363507e-22,
#  '111100010': 1.1876357332363507e-22,
#  '111101111': 1.1876357332363507e-22,
#  '111110111': 1.1876357332363507e-22,
#  '111111011': 1.1876357332363507e-22,
#  '111111101': 1.1876357332363507e-22,
#  '111111110': 1.1876357332363507e-22,
#  '111111111': 1.1876357332363507e-22,
#  '000001010': 1.3365079474258814e-29,
#  '000001100': 1.3365079474258814e-29,
#  '000001110': 1.3365079474258814e-29,
#  '000010001': 1.3365079474258814e-29,
#  '000010100': 1.3365079474258814e-29,
#  '000010101': 1.3365079474258814e-29,
#  '000011100': 1.3365079474258814e-29,
#  '000100001': 1.3365079474258814e-29,
#  '000100010': 1.3365079474258814e-29,
#  '000100011': 1.3365079474258814e-29,
#  '000101010': 1.3365079474258814e-29,
#  '000110001': 1.3365079474258814e-29,
#  '001000010': 1.3365079474258814e-29,
#  '001000100': 1.3365079474258814e-29,
#  '001000110': 1.3365079474258814e-29,
#  '001001010': 1.3365079474258814e-29,
#  '001001100': 1.3365079474258814e-29,
#  '001010000': 1.3365079474258814e-29,
#  '001010001': 1.3365079474258814e-29,
#  '001010010': 1.3365079474258814e-29,
#  '001100000': 1.3365079474258814e-29,
#  '001100001': 1.3365079474258814e-29,
#  '001100100': 1.3365079474258814e-29,
#  '001110000': 1.3365079474258814e-29,
#  '001110111': 1.3365079474258814e-29,
#  '001111110': 1.3365079474258814e-29,
#  '010000001': 1.3365079474258814e-29,
#  '010000100': 1.3365079474258814e-29,
#  '010000101': 1.3365079474258814e-29,
#  '010001000': 1.3365079474258814e-29,
#  '010001001': 1.3365079474258814e-29,
#  '010001010': 1.3365079474258814e-29,
#  '010010001': 1.3365079474258814e-29,
#  '010010100': 1.3365079474258814e-29,
#  '010100000': 1.3365079474258814e-29,
#  '010100010': 1.3365079474258814e-29,
#  '010100100': 1.3365079474258814e-29,
#  '010101000': 1.3365079474258814e-29,
#  '010101111': 1.3365079474258814e-29,
#  '010111101': 1.3365079474258814e-29,
#  '011000100': 1.3365079474258814e-29,
#  '011011101': 1.3365079474258814e-29,
#  '011011110': 1.3365079474258814e-29,
#  '011100000': 1.3365079474258814e-29,
#  '011100111': 1.3365079474258814e-29,
#  '011101011': 1.3365079474258814e-29,
#  '011101101': 1.3365079474258814e-29,
#  '011101111': 1.3365079474258814e-29,
#  '011110011': 1.3365079474258814e-29,
#  '011110110': 1.3365079474258814e-29,
#  '011110111': 1.3365079474258814e-29,
#  '011111100': 1.3365079474258814e-29,
#  '011111101': 1.3365079474258814e-29,
#  '011111110': 1.3365079474258814e-29,
#  '100000001': 1.3365079474258814e-29,
#  '100000010': 1.3365079474258814e-29,
#  '100000011': 1.3365079474258814e-29,
#  '100001000': 1.3365079474258814e-29,
#  '100001001': 1.3365079474258814e-29,
#  '100001100': 1.3365079474258814e-29,
#  '100010000': 1.3365079474258814e-29,
#  '100010010': 1.3365079474258814e-29,
#  '100010100': 1.3365079474258814e-29,
#  '100011000': 1.3365079474258814e-29,
#  '100011111': 1.3365079474258814e-29,
#  '100100001': 1.3365079474258814e-29,
#  '100100010': 1.3365079474258814e-29,
#  '100111011': 1.3365079474258814e-29,
#  '101000010': 1.3365079474258814e-29,
#  '101010000': 1.3365079474258814e-29,
#  '101010111': 1.3365079474258814e-29,
#  '101011011': 1.3365079474258814e-29,
#  '101011101': 1.3365079474258814e-29,
#  '101011111': 1.3365079474258814e-29,
#  '101101011': 1.3365079474258814e-29,
#  '101101110': 1.3365079474258814e-29,
#  '101110101': 1.3365079474258814e-29,
#  '101110110': 1.3365079474258814e-29,
#  '101110111': 1.3365079474258814e-29,
#  '101111010': 1.3365079474258814e-29,
#  '101111011': 1.3365079474258814e-29,
#  '101111110': 1.3365079474258814e-29,
#  '110000001': 1.3365079474258814e-29,
#  '110001000': 1.3365079474258814e-29,
#  '110001111': 1.3365079474258814e-29,
#  '110011011': 1.3365079474258814e-29,
#  '110011110': 1.3365079474258814e-29,
#  '110011111': 1.3365079474258814e-29,
#  '110101101': 1.3365079474258814e-29,
#  '110101110': 1.3365079474258814e-29,
#  '110101111': 1.3365079474258814e-29,
#  '110110011': 1.3365079474258814e-29,
#  '110110101': 1.3365079474258814e-29,
#  '110111001': 1.3365079474258814e-29,
#  '110111011': 1.3365079474258814e-29,
#  '110111101': 1.3365079474258814e-29,
#  '111001110': 1.3365079474258814e-29,
#  '111010101': 1.3365079474258814e-29,
#  '111011100': 1.3365079474258814e-29,
#  '111011101': 1.3365079474258814e-29,
#  '111011110': 1.3365079474258814e-29,
#  '111100011': 1.3365079474258814e-29,
#  '111101010': 1.3365079474258814e-29,
#  '111101011': 1.3365079474258814e-29,
#  '111101110': 1.3365079474258814e-29,
#  '111110001': 1.3365079474258814e-29,
#  '111110011': 1.3365079474258814e-29,
#  '111110101': 1.3365079474258814e-29,
#  '001001110': 1.5040415537724992e-36,
#  '001010101': 1.5040415537724992e-36,
#  '001010110': 1.5040415537724992e-36,
#  '001011100': 1.5040415537724992e-36,
#  '001011110': 1.5040415537724992e-36,
#  '001100011': 1.5040415537724992e-36,
#  '001100110': 1.5040415537724992e-36,
#  '001101010': 1.5040415537724992e-36,
#  '001101110': 1.5040415537724992e-36,
#  '001110001': 1.5040415537724992e-36,
#  '001110010': 1.5040415537724992e-36,
#  '001110011': 1.5040415537724992e-36,
#  '001110100': 1.5040415537724992e-36,
#  '001110101': 1.5040415537724992e-36,
#  '001110110': 1.5040415537724992e-36,
#  '010001101': 1.5040415537724992e-36,
#  '010001110': 1.5040415537724992e-36,
#  '010010101': 1.5040415537724992e-36,
#  '010011100': 1.5040415537724992e-36,
#  '010011101': 1.5040415537724992e-36,
#  '010100011': 1.5040415537724992e-36,
#  '010100101': 1.5040415537724992e-36,
#  '010101001': 1.5040415537724992e-36,
#  '010101010': 1.5040415537724992e-36,
#  '010101011': 1.5040415537724992e-36,
#  '010101100': 1.5040415537724992e-36,
#  '010101101': 1.5040415537724992e-36,
#  '010101110': 1.5040415537724992e-36,
#  '010110001': 1.5040415537724992e-36,
#  '010110101': 1.5040415537724992e-36,
#  '011001100': 1.5040415537724992e-36,
#  '011001110': 1.5040415537724992e-36,
#  '011010100': 1.5040415537724992e-36,
#  '011010101': 1.5040415537724992e-36,
#  '011011100': 1.5040415537724992e-36,
#  '011100001': 1.5040415537724992e-36,
#  '011100010': 1.5040415537724992e-36,
#  '011100011': 1.5040415537724992e-36,
#  '011100100': 1.5040415537724992e-36,
#  '011100101': 1.5040415537724992e-36,
#  '011100110': 1.5040415537724992e-36,
#  '011101010': 1.5040415537724992e-36,
#  '011101100': 1.5040415537724992e-36,
#  '011110001': 1.5040415537724992e-36,
#  '011110100': 1.5040415537724992e-36,
#  '100001011': 1.5040415537724992e-36,
#  '100001110': 1.5040415537724992e-36,
#  '100010011': 1.5040415537724992e-36,
#  '100010101': 1.5040415537724992e-36,
#  '100011001': 1.5040415537724992e-36,
#  '100011010': 1.5040415537724992e-36,
#  '100011011': 1.5040415537724992e-36,
#  '100011100': 1.5040415537724992e-36,
#  '100011101': 1.5040415537724992e-36,
#  '100011110': 1.5040415537724992e-36,
#  '100100011': 1.5040415537724992e-36,
#  '100101010': 1.5040415537724992e-36,
#  '100101011': 1.5040415537724992e-36,
#  '100110001': 1.5040415537724992e-36,
#  '100110011': 1.5040415537724992e-36,
#  '101001010': 1.5040415537724992e-36,
#  '101001110': 1.5040415537724992e-36,
#  '101010001': 1.5040415537724992e-36,
#  '101010010': 1.5040415537724992e-36,
#  '101010011': 1.5040415537724992e-36,
#  '101010100': 1.5040415537724992e-36,
#  '101010101': 1.5040415537724992e-36,
#  '101010110': 1.5040415537724992e-36,
#  '101011010': 1.5040415537724992e-36,
#  '101011100': 1.5040415537724992e-36,
#  '101100010': 1.5040415537724992e-36,
#  '101100011': 1.5040415537724992e-36,
#  '101101010': 1.5040415537724992e-36,
#  '101110001': 1.5040415537724992e-36,
#  '101110010': 1.5040415537724992e-36,
#  '110001001': 1.5040415537724992e-36,
#  '110001010': 1.5040415537724992e-36,
#  '110001011': 1.5040415537724992e-36,
#  '110001100': 1.5040415537724992e-36,
#  '110001101': 1.5040415537724992e-36,
#  '110001110': 1.5040415537724992e-36,
#  '110010001': 1.5040415537724992e-36,
#  '110010101': 1.5040415537724992e-36,
#  '110011001': 1.5040415537724992e-36,
#  '110011100': 1.5040415537724992e-36,
#  '110100001': 1.5040415537724992e-36,
#  '110100011': 1.5040415537724992e-36,
#  '110101001': 1.5040415537724992e-36,
#  '110101010': 1.5040415537724992e-36,
#  '110110001': 1.5040415537724992e-36,
#  '001010100': 1.6925757903881418e-43,
#  '001100010': 1.6925757903881418e-43,
#  '010001100': 1.6925757903881418e-43,
#  '010100001': 1.6925757903881418e-43,
#  '011101110': 1.6925757903881418e-43,
#  '011110101': 1.6925757903881418e-43,
#  '100001010': 1.6925757903881418e-43,
#  '100010001': 1.6925757903881418e-43,
#  '101011110': 1.6925757903881418e-43,
#  '101110011': 1.6925757903881418e-43,
#  '110011101': 1.6925757903881418e-43,
#  '110101011': 1.6925757903881418e-43}

# %%
kl_divergence(exact_sampled_model.boltzmann_pd, qamcmc_chain_2.get_accepted_dict(normalize= True))
# Out:
# 0.02704417245715795

# %% [markdown]
# #### **Proposition Strategy Analysis**

# %% [markdown]
# Here we analyse the main adavnatge of the Quantum Enhanced MCMC routine, which is to propose transitions which are are more likely to be accepted when compared to usual classical proposition strategies. In the subsequent plots we compare statistics of all proposed transitions with respect to the *Acceptance-Probabilities* , *Energy-Difference*, and the *Hamming-Distance*.

# %% [markdown]
# **Acceptance-Probabilities**

# %%
plt.figure(figsize=(10,10))

bins = np.linspace(np.log10(np.min([np.min(qumcm1_statistic['acceptance_prob']),
                                    np.min(qumcm2_statistic['acceptance_prob']),
                                    np.min(cl_statistic['acceptance_prob'])]))-0.1, 0, num=30)

plt.hist(np.log10(qumcm1_statistic['acceptance_prob']),label= 'quantum enhanced Xi' , alpha= 0.8, bins= bins, density=True)
plt.hist(np.log10(qumcm2_statistic['acceptance_prob']),label= 'quantum enhanced XiXi+1' , alpha= 0.8, bins= bins, density=True)
plt.hist(np.log10(cl_statistic['acceptance_prob']),label= 'classical uniform' ,alpha= 0.5, bins= bins, density=True)


# plt.xscale("log")

plt.xlabel("Acceptance Probabilities | scale: log10")
plt.ylabel("Normalized Counts")
plt.legend()
plt.show()

# %% [markdown]
# The plot depicts that the *Acceptance-Probability* for the *quantum-enhanced* sampling is skewed towards unity, whereas for the *classical-uniform* sampling it is barely close to unity for most of th cases leading to a large rejection rate of the proposed moves.

# %% [markdown]
# **Energy-Difference**

# %%
plt.figure(figsize=(10,10))

bins = np.linspace(0, np.max(cl_statistic['energy'])+0.1, num=30)

plt.hist(qumcm1_statistic['energy'],label= 'quantum enhanced Xi' , alpha= 0.8, bins= bins)
plt.hist(qumcm2_statistic['energy'],label= 'quantum enhanced XiXi+1' , alpha= 0.8, bins= bins)
plt.hist(cl_statistic['energy'],label= 'classical uniform' ,alpha= 0.5, bins= bins)


# plt.xscale("log")

plt.xlabel("Energy-Difference Statistics")
# plt.ylabel("Hamming Distance")
plt.legend()
plt.show()

# %% [markdown]
# The plot shows that the *Energy-Difference* of the propose transitions is low for the case of *quantum-enhanced* transitions compared to the *classical-uniform* sampling, this also explains the trend in *Acceptance-Probability* as it is directly dependent on the former.

# %% [markdown]
# **Hamming-Distance**

# %%
plt.figure(figsize=(10,10))

bins = np.arange(0, n_spins+1)


plt.bar(*np.unique(qumcm1_statistic['hamming'], return_counts=True),label= 'quantum enhanced Xi' , alpha= 0.8)
plt.bar(*np.unique(qumcm2_statistic['hamming'], return_counts=True),label= 'quantum enhanced XiXi+1' , alpha= 0.8)
plt.bar(*np.unique(cl_statistic['hamming'], return_counts=True),label= 'classical uniform' ,alpha= 0.5)


# plt.xscale("log")

plt.xlabel("Hamming-Distance Statistics")
# plt.ylabel("Hamming Distance")
plt.legend()
plt.show()

# %% [markdown]
# #### **Convergence Analysis**

# %% [markdown]
# ##### KL Divergence

# %%
kldiv_c = calculate_running_kl_divergence(exact_sampled_model.boltzmann_pd, cl_chain)
kldiv_q1 = calculate_running_kl_divergence(exact_sampled_model.boltzmann_pd, qamcmc_chain_1)
kldiv_q2 = calculate_running_kl_divergence(exact_sampled_model.boltzmann_pd, qamcmc_chain_2)

# %%
plt.figure(figsize=(10,8))
plt.plot(kldiv_c, label= 'classical-uniform')
plt.plot(kldiv_q1, label= 'quantum-enhanced Xi')
plt.plot(kldiv_q2, label= 'quantum-enhanced more X_i terms')
plt.xlabel("iterations ")
plt.ylabel("KL divergence")
plt.yscale('log')
# plt.xscale("log")
plt.legend()
plt.show()
